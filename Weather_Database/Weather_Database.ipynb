# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "City Weather Description": city_weather_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | lagoa
# Processing Record 3 of Set 1 | namatanai
# Processing Record 4 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 1 | hirara
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | abha
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | sheltozero
# Processing Record 16 of Set 1 | rio bravo
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | karangasem
# Processing Record 19 of Set 1 | kichera
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | ocos
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | komsomolskiy
# Processing Record 25 of Set 1 | floro
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | richards bay
# Processing Record 29 of Set 1 | pimentel
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | aklavik
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | hualmay
# Processing Record 37 of Set 1 | malanje
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | karratha
# Processing Record 45 of Set 1 | altamira
# Processing Record 46 of Set 1 | kosikha
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 1 | menongue
# Processing Record 50 of Set 1 | teterow
# Processing Record 1 of Set 2 | yerbogachen
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | vestmanna
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | doha
# Processing Record 8 of Set 2 | mandalgovi
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | matnog
# Processing Record 11 of Set 2 | poya
# Processing Record 12 of Set 2 | half moon bay
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | ola
# Processing Record 18 of Set 2 | turka
# Processing Record 19 of Set 2 | naze
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | raudeberg
# Processing Record 23 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 24 of Set 2 | northam
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | bathsheba
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 2 | jonesboro
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | guamuchil
# Processing Record 35 of Set 2 | santa isabel
# Processing Record 36 of Set 2 | matara
# Processing Record 37 of Set 2 | nishihara
# Processing Record 38 of Set 2 | noumea
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | berlevag
# Processing Record 41 of Set 2 | jalu
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | yar
# Processing Record 44 of Set 2 | pervomayskoye
# Processing Record 45 of Set 2 | melfi
# Processing Record 46 of Set 2 | bambanglipuro
# Processing Record 47 of Set 2 | plattsburgh
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | high level
# Processing Record 50 of Set 2 | codrington
# Processing Record 1 of Set 3 | praia
# Processing Record 2 of Set 3 | beruwala
# Processing Record 3 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | tura
# Processing Record 7 of Set 3 | skibbereen
# Processing Record 8 of Set 3 | ahipara
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | san patricio
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | gorodets
# Processing Record 15 of Set 3 | sembe
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | aci castello
# Processing Record 20 of Set 3 | gizo
# Processing Record 21 of Set 3 | tilichiki
# Processing Record 22 of Set 3 | yashkul
# Processing Record 23 of Set 3 | bud
# Processing Record 24 of Set 3 | aquiraz
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | conde
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | sindor
# Processing Record 29 of Set 3 | bontang
# Processing Record 30 of Set 3 | faaborg
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | sinnamary
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | camacha
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | tarakan
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | savonlinna
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | acapetahua
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | barguzin
# Processing Record 47 of Set 3 | mirabad
# Processing Record 48 of Set 3 | pak phanang
# Processing Record 49 of Set 3 | lata
# Processing Record 50 of Set 3 | atbasar
# Processing Record 1 of Set 4 | turbat
# Processing Record 2 of Set 4 | sistranda
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 4 | naantali
# Processing Record 6 of Set 4 | sept-iles
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 4 | huambo
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | valdivia
# Processing Record 13 of Set 4 | mahajanga
# Processing Record 14 of Set 4 | flin flon
# Processing Record 15 of Set 4 | kimbe
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | kulu
# Processing Record 19 of Set 4 | burgas
# Processing Record 20 of Set 4 | inhambane
# Processing Record 21 of Set 4 | korla
# Processing Record 22 of Set 4 | new norfolk
# Processing Record 23 of Set 4 | xining
# Processing Record 24 of Set 4 | nome
# Processing Record 25 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 4 | mogadishu
# Processing Record 27 of Set 4 | bonnyville
# Processing Record 28 of Set 4 | ambon
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | okha
# Processing Record 32 of Set 4 | meulaboh
# Processing Record 33 of Set 4 | upernavik
# Processing Record 34 of Set 4 | makat
# Processing Record 35 of Set 4 | shiringushi
# Processing Record 36 of Set 4 | kasama
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | watertown
# Processing Record 39 of Set 4 | linxia
# Processing Record 40 of Set 4 | osypenko
# Processing Record 41 of Set 4 | dole
# Processing Record 42 of Set 4 | wladyslawowo
# Processing Record 43 of Set 4 | airai
# Processing Record 44 of Set 4 | panzhihua
# Processing Record 45 of Set 4 | benghazi
# Processing Record 46 of Set 4 | el viejo
# Processing Record 47 of Set 4 | diffa
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | salalah
# Processing Record 50 of Set 4 | pointe michel
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | tuktoyaktuk
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | itoman
# Processing Record 5 of Set 5 | dukat
# Processing Record 6 of Set 5 | necochea
# Processing Record 7 of Set 5 | saint-georges
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | izumo
# Processing Record 10 of Set 5 | buin
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | banda aceh
# Processing Record 13 of Set 5 | saint-medard-en-jalles
# Processing Record 14 of Set 5 | sulingen
# Processing Record 15 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 16 of Set 5 | sioux lookout
# Processing Record 17 of Set 5 | athabasca
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | abu samrah
# Processing Record 20 of Set 5 | saint george
# Processing Record 21 of Set 5 | merano
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | akureyri
# Processing Record 24 of Set 5 | ingham
# Processing Record 25 of Set 5 | hare bay
# Processing Record 26 of Set 5 | lasa
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | shenjiamen
# Processing Record 31 of Set 5 | huilong
# Processing Record 32 of Set 5 | palmas bellas
# Processing Record 33 of Set 5 | lichuan
# Processing Record 34 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 5 | huarmey
# Processing Record 36 of Set 5 | erenhot
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | henties bay
# Processing Record 39 of Set 5 | te anau
# Processing Record 40 of Set 5 | ashqelon
# Processing Record 41 of Set 5 | charleston
# Processing Record 42 of Set 5 | melilla
# Processing Record 43 of Set 5 | general pico
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | paramonga
# Processing Record 46 of Set 5 | lixourion
# Processing Record 47 of Set 5 | lethem
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | yurty
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | constantine
# Processing Record 3 of Set 6 | miri
# Processing Record 4 of Set 6 | port hardy
# Processing Record 5 of Set 6 | narasannapeta
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | hailey
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | tierranueva
# Processing Record 10 of Set 6 | voh
# Processing Record 11 of Set 6 | taupo
# Processing Record 12 of Set 6 | brisbane
# Processing Record 13 of Set 6 | vilhena
# Processing Record 14 of Set 6 | sabang
# Processing Record 15 of Set 6 | tabas
# Processing Record 16 of Set 6 | aleksandrov gay
# Processing Record 17 of Set 6 | puerto baquerizo moreno
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | collie
# Processing Record 20 of Set 6 | kaura namoda
# Processing Record 21 of Set 6 | kysyl-syr
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | russell
# Processing Record 24 of Set 6 | san lorenzo de el escorial
# Processing Record 25 of Set 6 | balikpapan
# Processing Record 26 of Set 6 | rockingham
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | vila velha
# Processing Record 29 of Set 6 | bambous virieux
# Processing Record 30 of Set 6 | chuy
# Processing Record 31 of Set 6 | ballina
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | muisne
# Processing Record 34 of Set 6 | pampas
# Processing Record 35 of Set 6 | tocopilla
# Processing Record 36 of Set 6 | yushan
# Processing Record 37 of Set 6 | sao miguel do guama
# Processing Record 38 of Set 6 | camacari
# Processing Record 39 of Set 6 | luancheng
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | filadelfia
# Processing Record 42 of Set 6 | saint-pierre
# Processing Record 43 of Set 6 | novikovo
# Processing Record 44 of Set 6 | dubbo
# Processing Record 45 of Set 6 | leshukonskoye
# Processing Record 46 of Set 6 | panguna
# Processing Record 47 of Set 6 | kloulklubed
# Processing Record 48 of Set 6 | souillac
# Processing Record 49 of Set 6 | fairbanks
# Processing Record 50 of Set 6 | bandiagara
# Processing Record 1 of Set 7 | koboko
# Processing Record 2 of Set 7 | bahia honda
# Processing Record 3 of Set 7 | rio gallegos
# Processing Record 4 of Set 7 | gimbi
# Processing Record 5 of Set 7 | miles city
# Processing Record 6 of Set 7 | andros town
# Processing Record 7 of Set 7 | brae
# Processing Record 8 of Set 7 | kushiro
# Processing Record 9 of Set 7 | plomarion
# Processing Record 10 of Set 7 | monterey
# Processing Record 11 of Set 7 | saldanha
# Processing Record 12 of Set 7 | saint anthony
# Processing Record 13 of Set 7 | fukue
# Processing Record 14 of Set 7 | nipawin
# Processing Record 15 of Set 7 | hofn
# Processing Record 16 of Set 7 | zhigansk
# Processing Record 17 of Set 7 | oksfjord
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | vestmannaeyjar
# Processing Record 20 of Set 7 | nova varos
# Processing Record 21 of Set 7 | gorontalo
# Processing Record 22 of Set 7 | karwar
# Processing Record 23 of Set 7 | markova
# Processing Record 24 of Set 7 | tumut
# Processing Record 25 of Set 7 | oussouye
# Processing Record 26 of Set 7 | biskamzha
# Processing Record 27 of Set 7 | baykit
# Processing Record 28 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 7 | ust-tsilma
# Processing Record 30 of Set 7 | saint-joseph
# Processing Record 31 of Set 7 | isangel
# Processing Record 32 of Set 7 | sinazongwe
# Processing Record 33 of Set 7 | pangnirtung
# Processing Record 34 of Set 7 | fort nelson
# Processing Record 35 of Set 7 | shimoda
# Processing Record 36 of Set 7 | danshui
# Processing Record 37 of Set 7 | khasan
# Processing Record 38 of Set 7 | svarstad
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | tingo maria
# Processing Record 41 of Set 7 | hulan
# Processing Record 42 of Set 7 | porto novo
# Processing Record 43 of Set 7 | padang
# Processing Record 44 of Set 7 | abaza
# Processing Record 45 of Set 7 | kieta
# Processing Record 46 of Set 7 | jasper
# Processing Record 47 of Set 7 | bubaque
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | igarka
# Processing Record 50 of Set 7 | rabo de peixe
# Processing Record 1 of Set 8 | tupelo
# Processing Record 2 of Set 8 | antipolo
# Processing Record 3 of Set 8 | bairiki
# Processing Record 4 of Set 8 | dunedin
# Processing Record 5 of Set 8 | dothan
# Processing Record 6 of Set 8 | canutama
# Processing Record 7 of Set 8 | dongsheng
# Processing Record 8 of Set 8 | vardo
# Processing Record 9 of Set 8 | boyarka
# Processing Record 10 of Set 8 | lakes entrance
# Processing Record 11 of Set 8 | toora-khem
# Processing Record 12 of Set 8 | santa rosa
# Processing Record 13 of Set 8 | sao joao da barra
# Processing Record 14 of Set 8 | teya
# Processing Record 15 of Set 8 | howard
# Processing Record 16 of Set 8 | boyolangu
# Processing Record 17 of Set 8 | srandakan
# Processing Record 18 of Set 8 | sangar
# Processing Record 19 of Set 8 | kutum
# Processing Record 20 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 8 | west plains
# Processing Record 22 of Set 8 | harper
# Processing Record 23 of Set 8 | kigali
# Processing Record 24 of Set 8 | zolotukhino
# Processing Record 25 of Set 8 | rawson
# Processing Record 26 of Set 8 | palana
# Processing Record 27 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 8 | namtsy
# Processing Record 29 of Set 8 | kavieng
# Processing Record 30 of Set 8 | santiago del estero
# Processing Record 31 of Set 8 | mandera
# Processing Record 32 of Set 8 | omsukchan
# Processing Record 33 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 8 | saint-augustin
# Processing Record 35 of Set 8 | finspang
# Processing Record 36 of Set 8 | ullapool
# Processing Record 37 of Set 8 | mpulungu
# Processing Record 38 of Set 8 | srednekolymsk
# Processing Record 39 of Set 8 | anlu
# Processing Record 40 of Set 8 | maniitsoq
# Processing Record 41 of Set 8 | lupiro
# Processing Record 42 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 8 | panaba
# Processing Record 45 of Set 8 | dickinson
# Processing Record 46 of Set 8 | turukhansk
# Processing Record 47 of Set 8 | puerto leguizamo
# Processing Record 48 of Set 8 | adolfo lopez mateos
# Processing Record 49 of Set 8 | san antonio
# Processing Record 50 of Set 8 | port blair
# Processing Record 1 of Set 9 | shubarkuduk
# Processing Record 2 of Set 9 | victoria
# Processing Record 3 of Set 9 | lakatoro
# Processing Record 4 of Set 9 | ostersund
# Processing Record 5 of Set 9 | gamboma
# Processing Record 6 of Set 9 | baicheng
# Processing Record 7 of Set 9 | bonthe
# Processing Record 8 of Set 9 | okhotsk
# Processing Record 9 of Set 9 | cap malheureux
# Processing Record 10 of Set 9 | sladkovo
# Processing Record 11 of Set 9 | desnogorsk
# Processing Record 12 of Set 9 | khandbari
# Processing Record 13 of Set 9 | severnyy
# Processing Record 14 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 9 | kostomuksha
# Processing Record 16 of Set 9 | nabire
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | millinocket
# Processing Record 19 of Set 9 | knysna
# Processing Record 20 of Set 9 | kalmunai
# Processing Record 21 of Set 9 | cassilandia
# Processing Record 22 of Set 9 | muravlenko
# Processing Record 23 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 9 | hammerfest
# Processing Record 25 of Set 9 | ambilobe
# Processing Record 26 of Set 9 | karasburg
# Processing Record 27 of Set 9 | hobyo
# Processing Record 28 of Set 9 | zaraza
# Processing Record 29 of Set 9 | kantang
# Processing Record 30 of Set 9 | ouegoa
# Processing Record 31 of Set 9 | waingapu
# Processing Record 32 of Set 9 | lapa
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | mitu
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | wattegama
# Processing Record 38 of Set 9 | horsham
# Processing Record 39 of Set 9 | kruisfontein
# Processing Record 40 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 9 | grindavik
# Processing Record 43 of Set 9 | iberia
# Processing Record 44 of Set 9 | urusha
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | pandan
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | nigde
# Processing Record 50 of Set 9 | fatehpur
# Processing Record 1 of Set 10 | kudahuvadhoo
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | angoram
# Processing Record 4 of Set 10 | tuatapere
# Processing Record 5 of Set 10 | yatou
# Processing Record 6 of Set 10 | sulangan
# Processing Record 7 of Set 10 | salekhard
# Processing Record 8 of Set 10 | catabola
# Processing Record 9 of Set 10 | thinadhoo
# Processing Record 10 of Set 10 | the valley
# Processing Record 11 of Set 10 | puerto escondido
# Processing Record 12 of Set 10 | lieksa
# Processing Record 13 of Set 10 | sola
# Processing Record 14 of Set 10 | tual
# Processing Record 15 of Set 10 | honningsvag
# Processing Record 16 of Set 10 | dzhebariki-khaya
# Processing Record 17 of Set 10 | challapata
# Processing Record 18 of Set 10 | vila franca do campo
# Processing Record 19 of Set 10 | artyom
# Processing Record 20 of Set 10 | langreo
# Processing Record 21 of Set 10 | trumbull
# Processing Record 22 of Set 10 | ambulu
# Processing Record 23 of Set 10 | raymondville
# Processing Record 24 of Set 10 | nouadhibou
# Processing Record 25 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 10 | caranavi
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | impfondo
# Processing Record 29 of Set 10 | mali
# Processing Record 30 of Set 10 | itajuba
# Processing Record 31 of Set 10 | daru
# Processing Record 32 of Set 10 | mayumba
# Processing Record 33 of Set 10 | emerald
# Processing Record 34 of Set 10 | vaitape
# Processing Record 35 of Set 10 | mbabane
# Processing Record 36 of Set 10 | beloha
# Processing Record 37 of Set 10 | coracora
# Processing Record 38 of Set 10 | alpena
# Processing Record 39 of Set 10 | mullovka
# Processing Record 40 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 10 | sijunjung
# Processing Record 42 of Set 10 | kirkuk
# Processing Record 43 of Set 10 | valparaiso
# Processing Record 44 of Set 10 | wau
# Processing Record 45 of Set 10 | broome
# Processing Record 46 of Set 10 | magway
# Processing Record 47 of Set 10 | mange
# Processing Record 48 of Set 10 | aquitania
# Processing Record 49 of Set 10 | husavik
# Processing Record 50 of Set 10 | nanma
# Processing Record 1 of Set 11 | winnemucca
# Processing Record 2 of Set 11 | karlstad
# Processing Record 3 of Set 11 | lenger
# Processing Record 4 of Set 11 | santa isabel do rio negro
# Processing Record 5 of Set 11 | dharchula
# Processing Record 6 of Set 11 | ketchikan
# Processing Record 7 of Set 11 | saint-ambroise
# Processing Record 8 of Set 11 | provideniya
# Processing Record 9 of Set 11 | ulladulla
# Processing Record 10 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 11 | biasca
# Processing Record 12 of Set 11 | muros
# Processing Record 13 of Set 11 | kurayoshi
# Processing Record 14 of Set 11 | kikwit
# Processing Record 15 of Set 11 | kargil
# Processing Record 16 of Set 11 | hermagor
# Processing Record 17 of Set 11 | udachnyy
# Processing Record 18 of Set 11 | baiyin
# Processing Record 19 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 11 | geraldton
# Processing Record 21 of Set 11 | cabo san lucas
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | marmarion
# Processing Record 24 of Set 11 | timizart
# Processing Record 25 of Set 11 | ormara
# Processing Record 26 of Set 11 | dalbandin
# Processing Record 27 of Set 11 | malakal
# Processing Record 28 of Set 11 | atambua
# Processing Record 29 of Set 11 | hukuntsi
# Processing Record 30 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 11 | puerto ayacucho
# Processing Record 32 of Set 11 | svetlyy
# Processing Record 33 of Set 11 | moba
# Processing Record 34 of Set 11 | laguna
# Processing Record 35 of Set 11 | kishtwar
# Processing Record 36 of Set 11 | beringovskiy
# Processing Record 37 of Set 11 | talavera
# Processing Record 38 of Set 11 | yago
# Processing Record 39 of Set 11 | rosetta
# Processing Record 40 of Set 11 | kirakira
# Processing Record 41 of Set 11 | forestville
# Processing Record 42 of Set 11 | aykhal
# Processing Record 43 of Set 11 | ayan
# Processing Record 44 of Set 11 | kommunar
# Processing Record 45 of Set 11 | prince rupert
# Processing Record 46 of Set 11 | tynda
# Processing Record 47 of Set 11 | port-cartier
# Processing Record 48 of Set 11 | karabulak
# Processing Record 49 of Set 11 | scarborough
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | kibre mengist
# Processing Record 2 of Set 12 | shingu
# Processing Record 3 of Set 12 | gabi
# Processing Record 4 of Set 12 | jacareacanga
# Processing Record 5 of Set 12 | carballo
# Processing Record 6 of Set 12 | pitimbu
# Processing Record 7 of Set 12 | rusne
# Processing Record 8 of Set 12 | dali
# Processing Record 9 of Set 12 | cockburn town
# Processing Record 10 of Set 12 | atar
# Processing Record 11 of Set 12 | codajas
# Processing Record 12 of Set 12 | taman
# Processing Record 13 of Set 12 | lang son
# Processing Record 14 of Set 12 | lockport
# Processing Record 15 of Set 12 | shelburne
# Processing Record 16 of Set 12 | dire dawa
# Processing Record 17 of Set 12 | beni suef
# Processing Record 18 of Set 12 | ugoofaaru
# Processing Record 19 of Set 12 | mananara
# Processing Record 20 of Set 12 | port macquarie
# Processing Record 21 of Set 12 | bilibino
# Processing Record 22 of Set 12 | mesyagutovo
# Processing Record 23 of Set 12 | rosarito
# Processing Record 24 of Set 12 | kedrovka
# Processing Record 25 of Set 12 | kemin
# Processing Record 26 of Set 12 | ponnani
# Processing Record 27 of Set 12 | camiri
# Processing Record 28 of Set 12 | auki
# Processing Record 29 of Set 12 | westport
# Processing Record 30 of Set 12 | greeneville
# Processing Record 31 of Set 12 | quesnel
# Processing Record 32 of Set 12 | adrar
# Processing Record 33 of Set 12 | mackay
# Processing Record 34 of Set 12 | cooma
# Processing Record 35 of Set 12 | maracaju
# Processing Record 36 of Set 12 | banatsko novo selo
# Processing Record 37 of Set 12 | kuminskiy
# Processing Record 38 of Set 12 | takoradi
# Processing Record 39 of Set 12 | presidencia roque saenz pena
# Processing Record 40 of Set 12 | paita
# Processing Record 41 of Set 12 | mao
# Processing Record 42 of Set 12 | abu kamal
# Processing Record 43 of Set 12 | luderitz
# Processing Record 44 of Set 12 | cabedelo
# Processing Record 45 of Set 12 | muli
# Processing Record 46 of Set 12 | port hedland
# Processing Record 47 of Set 12 | santa maria
# Processing Record 48 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 12 | asaba
# Processing Record 1 of Set 13 | tynset
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | sorland
# Processing Record 4 of Set 13 | pasighat
# Processing Record 5 of Set 13 | lynn haven
# Processing Record 6 of Set 13 | bowen
# Processing Record 7 of Set 13 | oktyabrskoye
# Processing Record 8 of Set 13 | coquimbo
# Processing Record 9 of Set 13 | tazovskiy
# Processing Record 10 of Set 13 | liwale
# Processing Record 11 of Set 13 | sergeyevka
# Processing Record 12 of Set 13 | lircay
# Processing Record 13 of Set 13 | goryachegorsk
# Processing Record 14 of Set 13 | molokovo
# Processing Record 15 of Set 13 | uribia
# Processing Record 16 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 13 | goroka
# Processing Record 18 of Set 13 | port augusta
# Processing Record 19 of Set 13 | belyy yar
# Processing Record 20 of Set 13 | weihe
# Processing Record 21 of Set 13 | namibe
# Processing Record 22 of Set 13 | botshabelo
# Processing Record 23 of Set 13 | saint pete beach
# Processing Record 24 of Set 13 | ibra
# Processing Record 25 of Set 13 | rawatbhata
# Processing Record 26 of Set 13 | yantai
# Processing Record 27 of Set 13 | kochi
# Processing Record 28 of Set 13 | longhua
# Processing Record 29 of Set 13 | halifax
# Processing Record 30 of Set 13 | sampit
# Processing Record 31 of Set 13 | margate
# Processing Record 32 of Set 13 | labuhan
# Processing Record 33 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 13 | khuzdar
# Processing Record 35 of Set 13 | haines junction
# Processing Record 36 of Set 13 | vitim
# Processing Record 37 of Set 13 | nakhon phanom
# Processing Record 38 of Set 13 | linhai
# Processing Record 39 of Set 13 | tiksi
# Processing Record 40 of Set 13 | sayan
# Processing Record 41 of Set 13 | mazagao
# Processing Record 42 of Set 13 | taos
# Processing Record 43 of Set 13 | igrim
# Processing Record 44 of Set 13 | rovaniemi
# Processing Record 45 of Set 13 | chifeng
# Processing Record 46 of Set 13 | saint-marc-des-carrieres
# Processing Record 47 of Set 13 | methoni
# Processing Record 48 of Set 13 | gornopravdinsk
# Processing Record 49 of Set 13 | bahia blanca
# Processing Record 50 of Set 13 | taoudenni
# Processing Record 1 of Set 14 | ranfurly
# Processing Record 2 of Set 14 | nema
# Processing Record 3 of Set 14 | yabelo
# Processing Record 4 of Set 14 | mgandu
# Processing Record 5 of Set 14 | ayagoz
# Processing Record 6 of Set 14 | kaeo
# Processing Record 7 of Set 14 | talnakh
# Processing Record 8 of Set 14 | grand gaube
# Processing Record 9 of Set 14 | viedma
# Processing Record 10 of Set 14 | lewisporte
# Processing Record 11 of Set 14 | san carlos
# Processing Record 12 of Set 14 | samarinda
# Processing Record 13 of Set 14 | gijon
# Processing Record 14 of Set 14 | marawi
# Processing Record 15 of Set 14 | gilgit
# Processing Record 16 of Set 14 | chapais
# Processing Record 17 of Set 14 | ati
# Processing Record 18 of Set 14 | ladushkin
# Processing Record 19 of Set 14 | hanna
# Processing Record 20 of Set 14 | hami
# Processing Record 21 of Set 14 | hirado
# Processing Record 22 of Set 14 | bom jesus da lapa
# Processing Record 23 of Set 14 | arlit
# Processing Record 24 of Set 14 | quelimane
# Processing Record 25 of Set 14 | mayo
# Processing Record 26 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 27 of Set 14 | mehendiganj
# Processing Record 28 of Set 14 | kenai
# Processing Record 29 of Set 14 | strelka
# Processing Record 30 of Set 14 | mehamn
# Processing Record 31 of Set 14 | humberto de campos
# Processing Record 32 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 33 of Set 14 | jiangyou
# Processing Record 34 of Set 14 | chute-aux-outardes
# Processing Record 35 of Set 14 | usinsk
# Processing Record 36 of Set 14 | fare
# Processing Record 37 of Set 14 | chukhloma
# Processing Record 38 of Set 14 | phnum penh
# City not found. Skipping...
# Processing Record 39 of Set 14 | tommot
# Processing Record 40 of Set 14 | perigueux
# Processing Record 41 of Set 14 | nellikkuppam
# Processing Record 42 of Set 14 | urengoy
# Processing Record 43 of Set 14 | hay river
# Processing Record 44 of Set 14 | suleja
# Processing Record 45 of Set 14 | curuca
# Processing Record 46 of Set 14 | benxi
# Processing Record 47 of Set 14 | kalianget
# Processing Record 48 of Set 14 | salinas
# Processing Record 49 of Set 14 | potoci
# Processing Record 50 of Set 14 | stutterheim
# Processing Record 1 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 15 | iztapa
# Processing Record 4 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 15 | preeceville
# Processing Record 6 of Set 15 | nenjiang
# Processing Record 7 of Set 15 | moron
# Processing Record 8 of Set 15 | bantry
# Processing Record 9 of Set 15 | manokwari
# Processing Record 10 of Set 15 | waddan
# Processing Record 11 of Set 15 | mityana
# Processing Record 12 of Set 15 | tolaga bay
# Processing Record 13 of Set 15 | yumen
# Processing Record 14 of Set 15 | monrovia
# Processing Record 15 of Set 15 | pochutla
# Processing Record 16 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 15 | nemuro
# Processing Record 18 of Set 15 | devils lake
# Processing Record 19 of Set 15 | ajdabiya
# Processing Record 20 of Set 15 | indramayu
# Processing Record 21 of Set 15 | ocumare del tuy
# Processing Record 22 of Set 15 | rogers
# Processing Record 23 of Set 15 | jiuquan
# Processing Record 24 of Set 15 | walvis bay
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | buchanan
# Processing Record 27 of Set 15 | ciudad bolivar
# Processing Record 28 of Set 15 | moree
# Processing Record 29 of Set 15 | port moresby
# Processing Record 30 of Set 15 | ormond beach
# Processing Record 31 of Set 15 | massaguet
# Processing Record 32 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 33 of Set 15 | panjab
# Processing Record 34 of Set 15 | raga
# Processing Record 35 of Set 15 | marabba
# Processing Record 36 of Set 15 | shuiji
# Processing Record 37 of Set 15 | gat
# Processing Record 38 of Set 15 | jackson
# Processing Record 39 of Set 15 | panambi
# Processing Record 40 of Set 15 | kyra
# Processing Record 41 of Set 15 | hervey bay
# Processing Record 42 of Set 15 | izberbash
# Processing Record 43 of Set 15 | general roca
# Processing Record 44 of Set 15 | rocha
# Processing Record 45 of Set 15 | ojinaga
# Processing Record 46 of Set 15 | petukhovo
# Processing Record 47 of Set 15 | lamu
# Processing Record 48 of Set 15 | plainfield
# Processing Record 49 of Set 15 | baoqing
# Processing Record 50 of Set 15 | asyut
# Processing Record 1 of Set 16 | buon me thuot
# City not found. Skipping...
# Processing Record 2 of Set 16 | cavaillon
# Processing Record 3 of Set 16 | amapa
# Processing Record 4 of Set 16 | nazilli
# Processing Record 5 of Set 16 | coolum beach
# Processing Record 6 of Set 16 | opobo
# City not found. Skipping...
# Processing Record 7 of Set 16 | vanavara
# Processing Record 8 of Set 16 | krutinka
# Processing Record 9 of Set 16 | maria chiquita
# Processing Record 10 of Set 16 | locri
# Processing Record 11 of Set 16 | burnie
# Processing Record 12 of Set 16 | polis
# Processing Record 13 of Set 16 | cozumel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hilo  19.7297 -155.0900     73.13        83         100        1.99
# 1      Lagoa  39.0500  -27.9833     59.74        75          51       30.11
# 2  Namatanai  -3.6667  152.4333     79.23        82          92        3.22
# 3     Hirara  24.8000  125.2833     73.11        76         100       21.88
# 4  Busselton -33.6500  115.3333     53.42        92           1        7.83
# 5       Abha  18.2164   42.5053     57.45        77           0        0.00
# 6     Albany  42.6001  -73.9662     38.28        49          16        5.01
# 7      Kapaa  22.0752 -159.3190     70.12        88          75        3.44
# 8    Mataura -46.1927  168.8643     50.49        94          75        5.01
# 9  Ilulissat  69.2167  -51.1000     17.62        73          75       19.57
#
#   Country City Weather Description
# 0      US          overcast clouds
# 1      PT            broken clouds
# 2      PG               light rain
# 3      JP          overcast clouds
# 4      AU                clear sky
# 5      SA                clear sky
# 6      US               few clouds
# 7      US            broken clouds
# 8      NZ            broken clouds
# 9      GL               light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'City Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
